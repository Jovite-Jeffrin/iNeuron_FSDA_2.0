# %% [markdown]
# ### 1. What advantages do Excel spreadsheets have over CSV spreadsheets?
#
# A workbook's worksheet information is contained in a binary file.
#
# Data can be stored and processed in an Excel spreadsheet.
#
# Text editors are unable to open or edit Excel files.
#
# Excel makes it considerably simpler for end users to work with enormous files. Additionally, you can perform additional tasks like choosing certain cells to import.
#
# Automatic date and time conversion, reading formulas and their output, applying filters, sorting, etc.
#
# In addition to text, data can also be stored as graphs and charts.

# %% [markdown]
# ### 2.What do you pass to csv.reader() and csv.writer() to create reader and writer objects?

# %%
import csv
file1 = open('202212-divvy-tripdata.csv')
reader1 = csv.reader(file1)
Data = list(reader1)
Data
# Out:
# [['ride_id',
#   'rideable_type',
#   'started_at',
#   'ended_at',
#   'start_station_name',
#   'start_station_id',
#   'end_station_name',
#   'end_station_id',
#   'start_lat',
#   'start_lng',
#   'end_lat',
#   'end_lng',
#   'member_casual'],
#  ['65DBD2F447EC51C2',
#   'electric_bike',
#   '05-12-2022 10:47',
#   '05-12-2022 10:56',
#   'Clifton Ave & Armitage Ave',
#   'TA1307000163',
#   'Sedgwick St & Webster Ave',
#   '13191',
#   '41.9182435',
#   '-87.65711467',
#   '41.922167',
#   '-87.638888',
#   'member'],
#  ['0C201AA7EA0EA1AD',
#   'classic_bike',
#   '18-12-2022 06:42',
#   '18-12-2022 07:08',
#   'Broadway & Belmont Ave',
#   '13277',
#   'Sedgwick St & Webster Ave',
#   '13191',
#   '41.940106',
#   '-87.645451',
#   '41.922167',
#   '-87.638888',
#   'casual'],
#  ['E0B148CCB358A49D',
#   'electric_bike',
#   '13-12-2022 08:47',
#   '13-12-2022 08:59',
#   'Sangamon St & Lake St',
#   'TA1306000015',
#   'St. Clair St & Erie St',
#   '13016',
# ...

# %%
fields = ['ride_id',
  'rideable_type',
  'started_at',
  'ended_at',
  'start_station_name',
  'start_station_id',
  'end_station_name',
  'end_station_id',
  'start_lat',
  'start_lng',
  'end_lat',
  'end_lng',
  'member_casual']
	
# data rows of csv file
rows = ['6AD396CKJGHTDCC992',
  'classic_bike',
  '22-12-2022 09:02',
  '23-12-2022 09:19',
  'Leavitt St & Chicago Ave',
  '18058',
  'Wacker Dr & Washington St',
  'KA1503870072',
  '41.895501',
  '-87.682017',
  '41.88314336',
  '-87.63724208',
  'casual']

filename = "202212-divvy-tripdata.csv"

with open(filename, 'w') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(fields)
    csvwriter.writerows(rows)

# %% [markdown]
# ### 3. What modes do File objects for reader and writer objects need to be opened in?
#
# read-binary(rb): reader
#
# write-binary(wb): writer

# %% [markdown]
# ### 4. What method takes a list argument and writes it to a CSV file?
#
# writerow() method will take a list of arguments and will write it in the csv.

# %%
File2 = open('202212-divvy-tripdata.csv','w')
Writer2 = csv.writer(File2)
csv.writer(File2).writerow(['6AD396SDGEWEHTDCC992',
  'classic_bike',
  '20-12-2022 09:02',
  '23-12-2022 09:19',
  'Lovite St & Chicago Ave',
  '18058',
  'Wacker Dr & Washington St',
  'KA1503870072',
  '41.895501',
  '-87.682017',
  '41.88314336',
  '-87.63724208',
  'member'])
# Out:
# 191

# %% [markdown]
# ### 5. What do the keyword arguments delimiter and line terminator do?
# The string used to divide the cells in a row is altered by the delimiter argument.
#
# The string that is used to divide rows is altered by the line terminator argument.

# %% [markdown]
# ### 6. What function takes a string of JSON data and returns a Python data structure?
#
# json.loads() function takes a string of JSON data and returns a Python data structure

# %% [markdown]
# ### 7. What function takes a Python data structure and returns a string of JSON data?
#
# json.dumps() function takes a Python data structure and returns a string of JSON data
